# %%
import os
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw
import natsort 

def Mosaic(img_path,outfile):
    img_list   = []

    width      = 158 #684
    height     = 165 #1024

    rows       = 10
    columns    = 10

    filelist=[]
    for file in os.listdir(img_path):
        if file.endswith(".png"):
            filelist.append( file ) 


    sorted_files=natsort.natsorted(filelist)

    for file in sorted_files:    
        img_list.append( Image.open(img_path+ file ) )


    for image in img_list:
        # resize images
        image.thumbnail( (width, height) )

    columns = len(img_list)/rows

    #creates a new empty image, RGB mode
    mosaic = Image.new( 'RGB', (  int(columns * width), int(rows * height) ) )

    # Prepare draw and font objects to render text
    draw   = ImageDraw.Draw(mosaic)

    k=0
    for j in range( 0, int(columns * width), height ):
        for i in range( 0, int(columns * width), width ):
            # paste the image at location i,j:
            mosaic.paste( img_list[k], (i,j) )
            # Select next image and text
            k = k + 1

    # Save image to file
    mosaic.save(outfile)

# %%
tasks=['EMOTION','GAMBLING','LANGUAGE','MOTOR','RELATIONAL','SOCIAL','WM']
for task in tasks:    
    W1='/home/share/TmpData/Qinglin/HCP_Group_DBN/'+task+'_W1/'
    W2='/home/share/TmpData/Qinglin/HCP_Group_DBN/'+task+'_W2/'
    W3='/home/share/TmpData/Qinglin/HCP_Group_DBN/'+task+'_W3/'
    out1='/home/share/TmpData/Qinglin/HCP_Group_DBN/'+task+'_W1.png'
    out2='/home/share/TmpData/Qinglin/HCP_Group_DBN/'+task+'_W2.png'
    out3='/home/share/TmpData/Qinglin/HCP_Group_DBN/'+task+'_W3.png'
    Mosaic(W1,out1)
    Mosaic(W2,out1)
    Mosaic(W1,out1)
# Out:
# ['0.png',
#  '1.png',
#  '2.png',
#  '3.png',
#  '4.png',
#  '5.png',
#  '6.png',
#  '7.png',
#  '8.png',
#  '9.png',
#  '10.png',
#  '11.png',
#  '12.png',
#  '13.png',
#  '14.png',
#  '15.png',
#  '16.png',
#  '17.png',
#  '18.png',
#  '19.png',
#  '20.png',
#  '21.png',
#  '22.png',
#  '23.png',
#  '24.png',
#  '25.png',
#  '26.png',
#  '27.png',
#  '28.png',
#  '29.png',
#  '30.png',
#  '31.png',
#  '32.png',
#  '33.png',
#  '34.png',
#  '35.png',
#  '36.png',
#  '37.png',
#  '38.png',
#  '39.png',
#  '40.png',
#  '41.png',
#  '42.png',
#  '43.png',
#  '44.png',
#  '45.png',
#  '46.png',
#  '47.png',
#  '48.png',
#  '49.png',
#  '50.png',
#  '51.png',
#  '52.png',
#  '53.png',
#  '54.png',
#  '55.png',
#  '56.png',
#  '57.png',
#  '58.png',
#  '59.png',
#  '60.png',
#  '61.png',
#  '62.png',
#  '63.png',
#  '64.png',
#  '65.png',
#  '66.png',
#  '67.png',
#  '68.png',
#  '69.png',
#  '70.png',
#  '71.png',
#  '72.png',
#  '73.png',
#  '74.png',
#  '75.png',
#  '76.png',
# ...
